# %% [markdown]
# # 04 – Model Değerlendirme
# Test seti üzerinde performans ölçümü ve görselleştirme

# %%
# Bölüm 1: Import'lar
# TODO: pandas, numpy import et
# TODO: plotly, seaborn, matplotlib import et
# TODO: sys.path.append ile proje kök dizinini ekle
# TODO: src.load_data, src.models, src.evaluate modüllerini import et
pass

# %%
# Bölüm 2: Test seti üzerinde sınıflandırma tahminleri
# TODO: her coin için kaydedilmiş classifier modelini yükle (load_model)
# TODO: X_test üzerinde predict() ve predict_proba() çağır
# TODO: tahmin sonuçlarını DataFrame'e kaydet
pass

# %%
# Bölüm 3: Her coin için classification_metrics() tablosu
# TODO: her coin için classification_metrics() çağır
# TODO: sonuçları tek bir özet DataFrame'de topla
# TODO: en iyi performans gösteren coini yorumla
pass

# %%
# Bölüm 4: Her coin için regression_metrics() tablosu
# TODO: her coin için kaydedilmiş regressor modelini yükle
# TODO: X_test üzerinde predict() çağır
# TODO: regression_metrics() ile metrikleri hesapla ve tablo oluştur
pass

# %%
# Bölüm 5: compare_models() ile karşılaştırma
# TODO: sınıflandırma metrik sonuçlarını dict olarak topla
# TODO: compare_models() çağır
# TODO: en iyi modeli yorumla
pass

# %%
# Bölüm 6: Gerçek vs tahmin fiyat grafiği (Plotly)
# TODO: her coin için regresyon tahminlerini al
# TODO: Plotly go.Figure() ile gerçek close ve tahmin değerlerini çiz
# TODO: her coin için ayrı grafik veya subplot kullan
pass

# %%
# Bölüm 7: Confusion matrix heatmap
# TODO: her coin için confusion_matrix() hesapla
# TODO: seaborn heatmap ile görselleştir (annot=True)
# TODO: subplot ile tüm coinleri yan yana göster
pass

# %%
# Bölüm 8: Coin bazında F1 ve RMSE bar chart
# TODO: her coin için F1 ve RMSE değerlerini topla
# TODO: F1 için bar chart çiz (yüksek = iyi)
# TODO: RMSE için bar chart çiz (düşük = iyi)
# TODO: yan yana subplot olarak göster
pass
