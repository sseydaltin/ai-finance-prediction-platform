# %% [markdown]
# # 03 – Model Eğitimi
# XGBoost sınıflandırma ve regresyon modellerinin eğitimi ve kaydı

# %%
# Bölüm 1: Import'lar
# TODO: pandas, numpy import et
# TODO: sys.path.append ile proje kök dizinini ekle
# TODO: src.load_data, src.models modüllerini import et
# TODO: COINS ve MODELS_DIR sabitlerini import et
pass

# %%
# Bölüm 2: {ticker}_features.csv dosyalarını oku
# TODO: COINS üzerinde döngü kur
# TODO: data/processed/{ticker}_features.csv oku
# TODO: her coin için shape ve sütun sayısını yazdır
pass

# %%
# Bölüm 3: temporal_train_test_split() – bölme tarihlerini göster
# TODO: her coin için temporal_train_test_split() çağır
# TODO: train ve test setlerinin boyutlarını yazdır
# TODO: bölme tarihini ve train/test oranını kontrol et
pass

# %%
# Bölüm 4: Her coin için XGBoost classifier eğit ve kaydet
# TODO: COINS üzerinde döngü kur
# TODO: train_classifier(X_train, y_clf_train, ticker, 'xgboost') çağır
# TODO: her coin için train accuracy'i kaydet
# TODO: sonuçları tablo olarak göster
pass

# %%
# Bölüm 5: Her coin için XGBoost regressor eğit ve kaydet
# TODO: COINS üzerinde döngü kur
# TODO: train_regressor(X_train, y_reg_train, ticker, 'xgboost') çağır
# TODO: her coin için train RMSE'yi kaydet
# TODO: sonuçları tablo olarak göster
pass
