# %% [markdown]
# # 02 – Ön İşleme ve Öznitelik Mühendisliği
# İndikatör hesaplama ve feature pipeline hazırlığı

# %%
# Bölüm 1: Import'lar ve src modüllerini ekle (sys.path)
# TODO: pandas, numpy import et
# TODO: sys.path.append ile proje kök dizinini ekle
# TODO: src.load_data, src.indicators, src.engineering modüllerini import et
# TODO: COINS listesini import et
pass

# %%
# Bölüm 2: Her coin için load_processed() ile veri oku
# TODO: COINS listesi üzerinde döngü kur
# TODO: load_processed(ticker) çağır ve sonuçları dict'e kaydet
# TODO: her coin için shape ve ilk 5 satırı yazdır
pass

# %%
# Bölüm 3: Eksik değerleri forward fill ile doldur
# TODO: her coin DataFrame'inde ffill() uygula
# TODO: işlem öncesi ve sonrası eksik değer sayısını karşılaştır
# TODO: hâlâ eksik değer varsa yazdır
pass

# %%
# Bölüm 4: add_all_indicators() uygula
# TODO: her coin için add_all_indicators() çağır
# TODO: eklenen yeni sütun isimlerini yazdır
# TODO: örnek olarak BTC için son 5 satırı göster
pass

# %%
# Bölüm 5: prepare_features() uygula – feature listesini göster
# TODO: her coin için prepare_features() çağır
# TODO: final sütun listesini yazdır
# TODO: toplam feature sayısını ve dropna sonrası satır sayısını göster
pass

# %%
# Bölüm 6: data/processed/{ticker}_features.csv olarak kaydet
# TODO: her coin için to_csv() çağır
# TODO: kaydedilen dosya yolunu ve boyutunu yazdır
# TODO: kayıt doğrulaması için pd.read_csv ile geri oku ve shape kontrol et
pass
